# %% [markdown]
# <a href="https://colab.research.google.com/github/sudirja18/UTS_machinelearning_soal1/blob/main/UTSsoal_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
path_="/content/drive/My Drive/UTS_machine learning/data_2genre.csv"
dataset=pd.read_csv(path_)
dataset
# Out:
#                filename       tempo  beats  ...    mfcc19    mfcc20  label
# 0          pop.00024.au  117.453835     57  ...  1.493700  0.949931      1
# 1          pop.00099.au   78.302557     38  ...  1.609469  7.580263      1
# 2          pop.00009.au  107.666016     50  ...  1.569434 -1.724873      1
# 3          pop.00078.au  103.359375     52  ... -0.729631 -0.987611      1
# 4          pop.00037.au  103.359375     51  ... -0.612146 -4.050126      1
# ..                  ...         ...    ...  ...       ...       ...    ...
# 195  classical.00020.au  143.554688     69  ... -1.292084 -7.100527      2
# 196  classical.00072.au  117.453835     57  ... -3.253521  3.998950      2
# 197  classical.00061.au  151.999081     76  ... -5.246985 -5.270150      2
# 198  classical.00008.au  135.999178     67  ... -2.105312  0.755132      2
# 199  classical.00084.au  112.347147     25  ... -1.273307 -0.441167      2
#
# [200 rows x 30 columns]

# %%
dataset.head()
# Out:
#        filename       tempo  beats  ...    mfcc19    mfcc20  label
# 0  pop.00024.au  117.453835     57  ...  1.493700  0.949931      1
# 1  pop.00099.au   78.302557     38  ...  1.609469  7.580263      1
# 2  pop.00009.au  107.666016     50  ...  1.569434 -1.724873      1
# 3  pop.00078.au  103.359375     52  ... -0.729631 -0.987611      1
# 4  pop.00037.au  103.359375     51  ... -0.612146 -4.050126      1
#
# [5 rows x 30 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(dataset['tempo'],dataset['beats'])

# %%
plt.scatter(dataset['tempo'],dataset['chroma_stft'])

# %%
x=dataset[['tempo','beats']]
y=dataset['chroma_stft']

# %%
x
# Out:
#           tempo  beats
# 0    117.453835     57
# 1     78.302557     38
# 2    107.666016     50
# 3    103.359375     52
# 4    103.359375     51
# ..          ...    ...
# 195  143.554688     69
# 196  117.453835     57
# 197  151.999081     76
# 198  135.999178     67
# 199  112.347147     25
#
# [200 rows x 2 columns]

# %%
y
# Out:
# 0      0.410990
# 1      0.360462
# 2      0.454810
# 3      0.454698
# 4      0.451668
#          ...
# 195    0.269065
# 196    0.279421
# 197    0.281670
# 198    0.254774
# 199    0.245491
# Name: chroma_stft, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
len(x_train)
# Out:
# 140

# %%
len(x_test)
# Out:
# 60

# %%
x_train
# Out:
#           tempo  beats
# 145  143.554688     28
# 179  198.768029     96
# 106   95.703125     47
# 9     92.285156     45
# 129   95.703125     45
# ..          ...    ...
# 198  135.999178     67
# 159   95.703125     36
# 131  112.347147     51
# 154  107.666016     53
# 53   129.199219     61
#
# [140 rows x 2 columns]

# %%
x_test
# Out:
#           tempo  beats
# 139  143.554688     72
# 41    92.285156     46
# 95   129.199219     61
# 40   103.359375     50
# 62   151.999081     74
# 127   78.302557     40
# 81    83.354335     39
# 186  161.499023     79
# 100   92.285156     44
# 178  143.554688     66
# 25   129.199219     63
# 194  135.999178     68
# 112  151.999081     65
# 126  129.199219     37
# 2    107.666016     50
# 142   95.703125     45
# 143  135.999178     68
# 109  184.570312     94
# 61    95.703125     46
# 177  151.999081     59
# 170   71.777344     30
# 43   215.332031    109
# 10   103.359375     51
# 13   112.347147     56
# 128  184.570312     88
# 82    99.384014     49
# 105   67.999589     24
# 72   112.347147     53
# 197  151.999081     76
# 49    89.102909     44
# 74   107.666016     53
# 75   117.453835     57
# 134  129.199219     56
# 173  107.666016     44
# 23    99.384014     47
# 165  135.999178     67
# 107   89.102909     43
# 14    92.285156     42
# 153  184.570312     86
# ...

# %%
y_train
# Out:
# 145    0.303928
# 179    0.261728
# 106    0.284018
# 9      0.409987
# 129    0.333863
#          ...
# 198    0.254774
# 159    0.235658
# 131    0.303159
# 154    0.286159
# 53     0.390384
# Name: chroma_stft, Length: 140, dtype: float64

# %%
y_test
# Out:
# 139    0.265697
# 41     0.376549
# 95     0.292246
# 40     0.352268
# 62     0.330304
# 127    0.186564
# 81     0.384183
# 186    0.237426
# 100    0.223738
# 178    0.268582
# 25     0.407387
# 194    0.240705
# 112    0.266904
# 126    0.346798
# 2      0.454810
# 142    0.215813
# 143    0.187032
# 109    0.289979
# 61     0.366030
# 177    0.294410
# 170    0.234236
# 43     0.475726
# 10     0.353223
# 13     0.447461
# 128    0.369008
# 82     0.431417
# 105    0.225212
# 72     0.447051
# 197    0.281670
# 49     0.475361
# 74     0.412941
# 75     0.424473
# 134    0.216328
# 173    0.253793
# 23     0.422917
# 165    0.266760
# 107    0.256395
# 14     0.374629
# 153    0.236279
# 192    0.219015
# 169    0.305244
# 199    0.245491
# 7      0.393404
# 163    0.246935
# 171    0.276529
# 108    0.261489
# 78     0.369948
# 70     0.473440
# 146    0.219209
# 111    0.217627
# 55     0.339969
# 22     0.386800
# 87     0.322574
# 0      0.410990
# 181    0.217421
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
len(x_train)
# Out:
# 160

# %%
len(x_test)
# Out:
# 40

# %%
x_train
# Out:
#           tempo  beats
# 176  143.554688     69
# 158   86.132812     43
# 1     78.302557     38
# 181  117.453835     47
# 144  123.046875     55
# ..          ...    ...
# 96   151.999081     75
# 155   89.102909     32
# 178  143.554688     66
# 87    58.726918     28
# 169  123.046875     57
#
# [160 rows x 2 columns]

# %%
x_test
# Out:
#           tempo  beats
# 191  123.046875     52
# 86    92.285156     46
# 37   112.347147     53
# 28    83.354335     40
# 95   129.199219     61
# 186  161.499023     79
# 142   95.703125     45
# 111  143.554688     62
# 11    83.354335     40
# 132  172.265625     84
# 125   89.102909     18
# 168  151.999081     57
# 175   95.703125     46
# 163  135.999178     58
# 58    99.384014     47
# 25   129.199219     63
# 183  129.199219     60
# 124  117.453835     46
# 160  103.359375     48
# 20   129.199219     62
# 82    99.384014     49
# 91   117.453835     56
# 185  143.554688     66
# 177  151.999081     59
# 180   83.354335     40
# 60   107.666016     53
# 134  129.199219     56
# 4    103.359375     51
# 65   172.265625     82
# 187  135.999178     67
# 72   112.347147     53
# 26   107.666016     53
# 137   69.837416     32
# 147   95.703125     45
# 40   103.359375     50
# 103   95.703125     43
# 24   161.499023     79
# 22   103.359375     49
# 104  123.046875     62
# ...

# %%
y_train
# Out:
# 176    0.437909
# 158    0.227545
# 1      0.360462
# 181    0.217421
# 144    0.207163
#          ...
# 96     0.333196
# 155    0.198926
# 178    0.268582
# 87     0.322574
# 169    0.305244
# Name: chroma_stft, Length: 160, dtype: float64

# %%
y_test
# Out:
# 191    0.274434
# 86     0.400378
# 37     0.433487
# 28     0.349401
# 95     0.292246
# 186    0.237426
# 142    0.215813
# 111    0.217627
# 11     0.377454
# 132    0.260483
# 125    0.320225
# 168    0.243056
# 175    0.226775
# 163    0.246935
# 58     0.437183
# 25     0.407387
# 183    0.232114
# 124    0.244666
# 160    0.283134
# 20     0.465028
# 82     0.431417
# 91     0.345658
# 185    0.234086
# 177    0.294410
# 180    0.257275
# 60     0.496900
# 134    0.216328
# 4      0.451668
# 65     0.403854
# 187    0.226948
# 72     0.447051
# 26     0.412302
# 137    0.236666
# 147    0.181161
# 40     0.352268
# 103    0.312900
# 24     0.329643
# 22     0.386800
# 104    0.258572
# 130    0.270815
# Name: chroma_stft, dtype: float64
